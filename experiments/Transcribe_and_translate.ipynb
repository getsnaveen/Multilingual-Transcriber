# %%
pip install yt_dlp
# Out:
# Running cells with 'transcribe (Python 3.11.11)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n transcribe ipykernel --update-deps --force-reinstall'

# %%
import yt_dlp
"https://www.youtube.com/watch?v=xUsBJYgZ_bM"

ydl_opts = {}

def dwl_vid(video_url):
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([video_url])

channel = 1
while channel == 1:
    link_of_the_video = input("Copy & paste the URL of the YouTube video you want to download: ")
    zxt = link_of_the_video.strip()

    dwl_vid(zxt)
    channel = int(input("Enter 1 if you want to download more videos\nEnter 0 if you are done: "))
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=j1T5Y8tnplE
# [youtube] j1T5Y8tnplE: Downloading webpage
# [youtube] j1T5Y8tnplE: Downloading tv client config
# [youtube] j1T5Y8tnplE: Downloading player 6b3caec8
# [youtube] j1T5Y8tnplE: Downloading tv player API JSON
# [youtube] j1T5Y8tnplE: Downloading ios player API JSON
# [youtube] j1T5Y8tnplE: Downloading m3u8 information
# [info] Testing format 616
# WARNING: ffmpeg not found. The downloaded format may not be the best available. Installing ffmpeg is strongly recommended: https://github.com/yt-dlp/yt-dlp#dependencies
# [info] j1T5Y8tnplE: Downloading 1 format(s): 18
# [download] Destination: Back to Back Comedy Scenes 🤣｜ Aagadu ｜ Mahesh Babu ｜ Brahmanandam ｜ Tamannah ｜ Telugu Comedy scene [j1T5Y8tnplE].mp4
# [download] 100% of   52.28MiB in 00:00:05 at 10.22MiB/s

# %%
pip install audio-extract

# %%
from audio_extract import extract_audio

extract_audio(input_path=r"/content/1.webm", output_path="audio.mp3")

# %%
pip install faster-whisper srt

# %%
from faster_whisper import WhisperModel

model = WhisperModel('large-v3')

# %%
segments, info = model.transcribe('audio.mp3', language='en')

# %%
segments = list(segments)

# %%
for segment in segments:
    # print(segment.text)
    print("[%.2fs -> %.2fs] %s" %(segment.start, segment.end, segment.text))

# %%
from datetime import datetime, timedelta
import os
def AudioTranscriptiontoFile(inputpath:str, languatetoconvert:str, *args, **kwargs):
        model = WhisperModel('large-v3')
        transcribe,info = model.transcribe(audio= inputpath,
                                          language= languatetoconvert)
        segments = list(transcribe)
        counter = 0
        for segment in segments:
            startTime = segment.start
            endTime = segment.end
            text = segment.text
            segmentId = counter
            counter += 1
            segment = f"{segmentId}\n{startTime} --> {endTime}\n{text[1:] if text[0] is ' ' else text}\n\n"

            # srtFilename = os.path.join("SrtFiles", f"1.srt")
            with open("/content/sample_data/1.srt", 'w', encoding='utf-8') as srtFile:
                srtFile.write(segment)

# %%
AudioTranscriptiontoFile(inputpath="/content/audio.mp3", languatetoconvert= "en")

# %%
input = "audio.mp3"
res  = input.split(".")
res[0]
# Out:
# 'audio'

# %%
pip install moviepy
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: moviepy in c:\users\naveen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.1.2)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in c:\users\naveen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\naveen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in c:\users\naveen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (0.4.8)
# Requirement already satisfied: numpy>=1.25.0 in c:\users\naveen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (2.2.3)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\naveen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: python-dotenv>=0.10 in c:\users\naveen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (1.0.1)
# Requirement already satisfied: pillow<11.0,>=9.2.0 in c:\users\naveen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (10.4.0)
# Requirement already satisfied: tqdm in c:\users\naveen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from proglog<=1.0.0->moviepy) (4.67.1)
# Requirement already satisfied: colorama in c:\users\naveen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm->proglog<=1.0.0->moviepy) (0.4.6)

# %%
import sys
import pysrt
from moviepy.video.io import  VideoFileClip
from moviepy import TextClip
from moviepy.video.compositing import  CompositeVideoClip


def time_to_seconds(time_obj):
    return time_obj.hours * 3600 + time_obj.minutes * 60 + time_obj.seconds + time_obj.milliseconds / 1000


def create_subtitle_clips(subtitles, videosize,fontsize=24, font='Arial', color='yellow', debug = False):
    subtitle_clips = []

    for subtitle in subtitles:
        start_time = time_to_seconds(subtitle.start)
        end_time = time_to_seconds(subtitle.end)
        duration = end_time - start_time

        video_width, video_height = videosize
        
        text_clip = TextClip(subtitle.text, fontsize=fontsize, font=font, color=color, bg_color = 'black',size=(video_width*3/4, None), method='caption').set_start(start_time).set_duration(duration)
        subtitle_x_position = 'center'
        subtitle_y_position = video_height* 4 / 5 

        text_position = (subtitle_x_position, subtitle_y_position)                    
        subtitle_clips.append(text_clip.set_position(text_position))

    return subtitle_clips
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 3
#       1 import sys
#       2 import pysrt
# ----> 3 from moviepy.editor import VideoFileClip, TextClip, CompositeVideoClip
#       6 def time_to_seconds(time_obj):
#       7     return time_obj.hours * 3600 + time_obj.minutes * 60 + time_obj.seconds + time_obj.milliseconds / 1000
#
# ModuleNotFoundError: No module named 'moviepy.editor'

# %%
pip install pysrt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pysrt
#   Downloading pysrt-1.1.2.tar.gz (104 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting chardet (from pysrt)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Building wheels for collected packages: pysrt
#   Building wheel for pysrt (pyproject.toml): started
#   Building wheel for pysrt (pyproject.toml): finished with status 'done'
#   Created wheel for pysrt: filename=pysrt-1.1.2-py3-none-any.whl size=13522 sha256=6941c5f69dbff559099b1321306f91b724e8fdac5e52d43af508a086e5d8711a
#   Stored in directory: c:\users\naveen\appdata\local\pip\cache\wheels\6a\36\54\2aa8dc961885dfa7b0ebd45a57505f25039d79b4ea0fd9f29d
# Successfully built pysrt
# Installing collected packages: chardet, pysrt
# Successfully installed chardet-5.2.0 pysrt-1.1.2
# Note: you may need to restart the kernel to use updated packages.
